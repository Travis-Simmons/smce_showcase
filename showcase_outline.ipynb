# %% [markdown]
# # Confluence Module Map

# %% [markdown]
# ![SegmentLocal](./images/cfl_workflow.png "segment")

# %% [markdown]
# # Confluence Data Flow

# %% [markdown]
# ![SegmentLocal](./images/swot_pixel_art.gif "segment")

# %% [markdown]
# ----------------------------------------
# # Confluence Modules
# -------------------------------

# %% [markdown]
# ## Input

# %% [markdown]
# - Turns SWOT observations into a single timeseries file per reach
# - Bringing code to the data

# %% [markdown]
# ## Priors

# %% [markdown]
# - show steve figure

# %% [markdown]
# ## Discharge Algorithms and Integration

# %% [markdown]
# ![SegmentLocal](./images/algo_results_2.png "segment")

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# # The Future
# -------------------------

# %% [markdown]
# ## HLS AIST

# %%
from smce_display_functions.hls_from_reach_id import *


data_dir = '/mnt/work/data/mnt/input/sword'
reach_id = 74270100221

all_links =  find_download_links_for_reach_tiles(data_dir, reach_id)

hls_da = rioxarray.open_rasterio(list(all_links)[0], chuncks=True)

orig_map=plt.cm.get_cmap('viridis')
  

reversed_map = orig_map.reversed()

imgplot = plt.imshow(hls_da.values[0], cmap=reversed_map)
# Out:
# Searching across 1 continents for nodes...
# Found 42 nodes...
# /home/travis/anaconda3/envs/hls/lib/python3.8/site-packages/geopandas/array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)

# %% [markdown]
# ## Lakeflow

# %% [markdown]
# ![SegmentLocal](./images/lakeflow.png "segment")

# %% [markdown]
# ## CUHASI
#
# ![SegmentLocal](./images/hydroshare.png "segment")

# %% [markdown]
# ## SMCE
#
# - Workflow Optimization
# - Costing
# - Security
# - Inter-SWOT collaboration
