# %% [markdown]
# -----------------------------------------
# # Confluence Introduction
# -----------------------------------------

# %% [markdown]
# ## Module Map

# %% [markdown]
# ![SegmentLocal](./images/cfl_workflow.png "segment")

# %% [markdown]
# ## Data Flow

# %% [markdown]
# ![SegmentLocal](./images/swot_pixel_art.gif "segment")

# %% [markdown]
# ----------------------------------------
# # Confluence Modules
# -------------------------------

# %% [markdown]
# ## Input

# %% [markdown]
# - Turns SWOT observations into a single timeseries file per reach
# - Bringing code to the data

# %% [markdown]
# ## Priors

# %% [markdown]
# ![SegmentLocal](./images/SOSgage.png "segment")

# %% [markdown]
# ## Discharge Algorithms and Integration

# %% [markdown]
# ![SegmentLocal](./images/algo_results_2.png "segment")

# %% [markdown]
# --------------------------
# # The Future
# -------------------------
#
# - Funded by AIST, Jacqueline Lemoigne-Stewart
# - Suported by PO.DAAC, Suresh Vannan
# - Supported by EIS/SMCE, Denis Felikson and Sujay Kumar

# %% [markdown]
# ## HLS SSC

# %%
from smce_display_functions.hls_from_reach_id import *

reach_id = 74270100221

# Searching using CRM API
data_dir = '/media/confluence/work/data/mnt/input/sword'
all_links =  find_download_links_for_reach_tiles(data_dir, reach_id)


# Plotting
hls_da = rioxarray.open_rasterio(list(all_links)[2], chuncks=True)
orig_map=plt.cm.get_cmap('viridis')
reversed_map = orig_map.reversed()
imgplot = plt.imshow(hls_da.values[0], cmap='viridis')
# Out:
# Searching across 1 continents for nodes...
# Found 42 nodes...

# %% [markdown]
# ## Lakeflow

# %% [markdown]
# ![SegmentLocal](./images/lakeflow.png "segment")

# %% [markdown]
# ## CUHASI

# %% [markdown]
# ![SegmentLocal](./images/hydroshare.png "segment")

# %% [markdown]
# ## SMCE
#
# - Workflow Optimization
# - Costing
# - Security
# - Inter-SWOT collaboration
# - Helping to get to TRL 8 via profiling and optimization
