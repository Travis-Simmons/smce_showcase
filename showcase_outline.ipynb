# %% [markdown]
# # Confluence Module Map

# %% [markdown]
# ![SegmentLocal](./images/cfl_workflow.png "segment")

# %% [markdown]
# # Confluence Data Flow

# %% [markdown]
# ![SegmentLocal](./images/swot_pixel_art.gif "segment")

# %% [markdown]
# ## Input

# %% [markdown]
# - Turns SWOT observations into a single timeseries file per reach
# - Requires close support from PO.DAAC
# - Bringing code to the data

# %% [markdown]
# ## Priors

# %% [markdown]
# - show steve figure

# %% [markdown]
# ## FLPE Algos and Integration

# %% [markdown]
# - Metroman Demonstration
#
# - cd /mnt/work/repos/smce_showcase
# - python3 /mnt/work/repos/confluence/confluence-local/build_and_run_module.py -n metroman -ad /mnt/work/repos/confluence/metroman/

# %% [markdown]
# ![SegmentLocal](./images/algo_results_2.png "segment")

# %% [markdown]
# ## Offline

# %% [markdown]
# - Replica of science team postprocessing
# - Improve turn around time of results for mission essential data product

# %% [markdown]
# ## Validation

# %% [markdown]
# - Uses worldwide gauge data to validate discharge estimates

# %% [markdown]
# ## Output

# %% [markdown]
# - Send it over to the science team!

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# # The Future
# -------------------------

# %% [markdown]
# ## HLS AIST

# %%
from smce_display_functions.hls_from_reach_id import *


data_dir = '/mnt/work/data/mnt/input/sword'
reach_id = 74270100221

all_links =  find_download_links_for_reach_tiles(data_dir, reach_id)

hls_da = rioxarray.open_rasterio(list(all_links)[0], chuncks=True)

imgplot = plt.imshow(hls_da.values[0])
# Out:
# Searching across 1 continents for nodes...
# Found 42 nodes...

# %% [markdown]
# ## Lakeflow

# %% [markdown]
# - have code showing lake

# %% [markdown]
# ## CUHASI
#
# ![SegmentLocal](./images/hydroshare.png "segment")

# %% [markdown]
# ## SMCE
#
# - Workflow Optimization
# - Costing
# - Security
# - Inter-SWOT collaboration
